# %%
! pip install pandas

# %%
import pandas as pd

url1 = 'dataset/credit_risk_dataset.csv'

pd.read_csv(url1,sep =',')
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
dados = pd.read_csv(url1)

# %%
dados.head(300)
# Out:
#      person_age  person_income person_home_ownership  person_emp_length  \
# 0            22          59000                  RENT              123.0
# 1            21           9600                   OWN                5.0
# 2            25           9600              MORTGAGE                1.0
# 3            23          65500                  RENT                4.0
# 4            24          54400                  RENT                8.0
# ..          ...            ...                   ...                ...
# 295          23          93000                  RENT                0.0
# 296          22         175000                  RENT                6.0
# 297          23         175000              MORTGAGE                3.0
# 298          25         174708                  RENT                9.0
# 299          25         174000              MORTGAGE                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
dados.tail(10)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32571          60          45600                  RENT                1.0
# 32572          52          52000                   OWN                0.0
# 32573          56          90000              MORTGAGE                0.0
# 32574          52          65004                  RENT                4.0
# 32575          52          64500                  RENT                0.0
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32571          VENTURE          B      20000          10.00            1
# ...

# %%
dados.shape
# Out:
# (32581, 12)

# %%
dados.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
import pandas as pd

# Supondo que 'dados' seja o seu DataFrame
dados.rename(columns={
    'person_age': 'idade_pessoa',
    'person_income': 'renda_pessoa',
    'person_home_ownership': 'propriedade_imovel_pessoa',
    'person_emp_length': 'tempo_emprego_pessoa',
    'loan_intent': 'intencao_emprestimo',
    'loan_grade': 'classe_emprestimo',
    'loan_amnt': 'valor_emprestimo',
    'loan_int_rate': 'taxa_juros_emprestimo',
    'loan_status': 'status_emprestimo',
    'loan_percent_income': 'percentual_renda_emprestimo',
    'cb_person_default_on_file': 'default_pessoa_no_arquivo',
    'cb_person_cred_hist_length': 'comprimento_historico_credito_pessoa'
}, inplace=True)

# %%
dados
# Out:
#        idade_pessoa  renda_pessoa propriedade_imovel_pessoa  \
# 0                22         59000                      RENT
# 1                21          9600                       OWN
# 2                25          9600                  MORTGAGE
# 3                23         65500                      RENT
# 4                24         54400                      RENT
# ...             ...           ...                       ...
# 32576            57         53000                  MORTGAGE
# 32577            54        120000                  MORTGAGE
# 32578            65         76000                      RENT
# 32579            56        150000                  MORTGAGE
# 32580            66         42000                      RENT
#
#        tempo_emprego_pessoa intencao_emprestimo classe_emprestimo  \
# 0                     123.0            PERSONAL                 D
# 1                       5.0           EDUCATION                 B
# ...

# %% [markdown]
# ## verificar e contar pessoas de 20 a 30 , de 30 a 40, de 40 a 50 , de 50 a 60

# %%
pessoas_ate_30 = dados[dados['idade_pessoa'] <=30 ]

x = pessoas_ate_30.shape[0]

print(f'existem : {x} pessoas ate 30 anos ')
# Out:
# existem : 24824 pessoas ate 30 anos

# %%
pessoas_ate_40 = dados[(dados['idade_pessoa'] > 30) & (dados['idade_pessoa'] <= 40)]


y = pessoas_ate_40.shape[0]

print(f'Existem {y} pessoas com mais de 31 e até 40 anos.')
# Out:
# Existem 6263 pessoas com mais de 31 e até 40 anos.

# %%
pessoas_ate_50 = dados[(dados['idade_pessoa'] > 40) & (dados['idade_pessoa'] <= 50)]


a = pessoas_ate_50.shape[0]

print(f'Existem {a} pessoas de 41 e até 50 anos.')
# Out:
# Existem 1206 pessoas de 41 e até 50 anos.

# %%
pessoas_ate_60 = dados[(dados['idade_pessoa'] > 50) & (dados['idade_pessoa'] <= 60)]


b = pessoas_ate_60.shape[0]

print(f'Existem {b} pessoas com mais de 51 e até 60 anos.')
# Out:
# Existem 218 pessoas com mais de 51 e até 60 anos.

# %%
pessoas_maiores_61 = dados[(dados['idade_pessoa'] > 61)]


c = pessoas_maiores_61.shape[0]

print(f'Existem {c} pessoas maiores de 61 anos')
# Out:
# Existem 61 pessoas maiores de 61 anos

# %%
import numpy

# %%
dados
# Out:
#        idade_pessoa  renda_pessoa propriedade_imovel_pessoa  \
# 0                22         59000                      RENT
# 1                21          9600                       OWN
# 2                25          9600                  MORTGAGE
# 3                23         65500                      RENT
# 4                24         54400                      RENT
# ...             ...           ...                       ...
# 32576            57         53000                  MORTGAGE
# 32577            54        120000                  MORTGAGE
# 32578            65         76000                      RENT
# 32579            56        150000                  MORTGAGE
# 32580            66         42000                      RENT
#
#        tempo_emprego_pessoa intencao_emprestimo classe_emprestimo  \
# 0                     123.0            PERSONAL                 D
# 1                       5.0           EDUCATION                 B
# ...

# %%
dados.describe()
# Out:
#        idade_pessoa  renda_pessoa  tempo_emprego_pessoa  valor_emprestimo  \
# count  32581.000000  3.258100e+04          31686.000000      32581.000000
# mean      27.734600  6.607485e+04              4.789686       9589.371106
# std        6.348078  6.198312e+04              4.142630       6322.086646
# min       20.000000  4.000000e+03              0.000000        500.000000
# 25%       23.000000  3.850000e+04              2.000000       5000.000000
# 50%       26.000000  5.500000e+04              4.000000       8000.000000
# 75%       30.000000  7.920000e+04              7.000000      12200.000000
# max      144.000000  6.000000e+06            123.000000      35000.000000
#
#        taxa_juros_emprestimo  status_emprestimo  percentual_renda_emprestimo  \
# count           29465.000000       32581.000000                 32581.000000
# mean               11.011695           0.218164                     0.170203
# ...

# %%
quartil = dados['idade_pessoa'].quantile()
quartil
# Out:
# np.float64(26.0)

# %%
media = dados['idade_pessoa'].mean()
media
# Out:
# np.float64(27.73459992019889)
